# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from model1.conv_layer import ConvLayer, get_predefined_filters
import numpy as np

# small test image (DO NOT use 512 yet)
image = np.random.rand(32, 32, 3)

filters = get_predefined_filters()

conv = ConvLayer(filters=filters)

output = conv.forward(image)

print("Output shape:", output.shape)
# Out:
# Output shape: (30, 30, 5)
